# %% [markdown]
# # Create a line plot!
# > ### This tutorial show how to create a line plot

# %%
a = [1,2,3,4]
b = [-1, -1, -3, -4]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(a,b)
plt.show()
